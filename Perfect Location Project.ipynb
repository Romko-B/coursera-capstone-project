# %% [markdown]
# # Part 1: explore neighbourhood

# %% [markdown]
# Import libraries

# %%
# !pip install BeautifulSoup4
# !pip install requests
# Out:
# Requirement already satisfied: BeautifulSoup4 in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from BeautifulSoup4) (1.7.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (2.21.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests) (2020.4.5.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests) (3.0.4)

# %% [markdown]
# Download data

# %%
#imports
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

#get html from wiki page and create soup object
source = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(source.text, 'lxml')

#using soup object, iterate the .wikitable to get the data from the HTML page and store it into a list
data = []
columns = []
table = soup.find(class_='wikitable')
for index, tr in enumerate(table.find_all('tr')):
    section = []
    for td in tr.find_all(['th','td']):
        section.append(td.text.rstrip())
    
    #First row of data is the header
    if (index == 0):
        columns = section
    else:
        data.append(section)

#convert list into Pandas DataFrame
canada_df = pd.DataFrame(data = data,columns = columns)
canada_df.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# Clean data

# %%
canada_df = canada_df[canada_df['Neighborhood'] != 'Not assigned']
canada_df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# Group by postal code

# %%
canada_df["Neighborhood"] = canada_df.groupby("Postal Code")["Neighborhood"].transform(lambda neigh: ', '.join(neigh))

#remove duplicates
canada_df = canada_df.drop_duplicates()

#update index to be postcode if it isn't already
if(canada_df.index.name != 'Postal Code'):
    canada_df = canada_df.set_index('Postal Code')
    
canada_df.head()
# Out:
#                       Borough                                 Neighborhood
# Postal Code
# M3A                North York                                    Parkwoods
# M4A                North York                             Victoria Village
# M5A          Downtown Toronto                    Regent Park, Harbourfront
# M6A                North York             Lawrence Manor, Lawrence Heights
# M7A          Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# Importing coordinates

# %%
df=pd.read_csv('http://cocl.us/Geospatial_data')
df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Concatenate tables

# %%
df = df.set_index('Postal Code')
df_combined = pd.concat([canada_df, df], axis=1, join='inner')

df_combined.index.name = 'Postal Code'
df_combined.reset_index(inplace=True)

df_combined.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %%
df_combined.shape
# Out:
# (103, 5)

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import requests
from pandas.io.json import json_normalize
import json

import requests

from bs4 import BeautifulSoup

from geopy.geocoders import Nominatim


import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

print('Libraries imported!')
# Out:
# Libraries imported!

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/a4/f0/44e69d50519880287cc41e7c8a6acc58daa9a9acf5f6afc52bcc70f69a6d/folium-0.11.0-py2.py3-none-any.whl (93kB)
#      |████████████████████████████████| 102kB 6.9MB/s ta 0:00:011
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/13/fb/9eacc24ba3216510c6b59a4ea1cd53d87f25ba76237d7f4393abeaf4c94e/branca-0.4.1-py3-none-any.whl
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.4.5.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.11.0

# %%
import folium

# %% [markdown]
# Set co-ordinates for Toronto

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="tl-toronto-neigh")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The co-ordinates of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The co-ordinates of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# Create a folium map of Toronto

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, long, post, borough, neigh in zip(df_combined['Latitude'], df_combined['Longitude'], df_combined['Postal Code'], df_combined['Borough'], df_combined['Neighborhood']):
    label = "{} ({}): {}".format(borough, post, neigh)
    popup = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, long],
        radius=5,
        popup=popup,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Part 2: check hotels in the neighbourhood

# %% [markdown]
# Set account credentials

# %%
CLIENT_ID = '3HSNMTNOB02MKCLT5PJR4ZUKFJQX5NRE42GDZZZIU2LVGGU1' # your Foursquare ID
CLIENT_SECRET = 'HPPDIJIDWVYKR1HKDQCJDTLE4I2WSBCULOSI0JKUTQJ1RQGO' # your Foursquare Secret
VERSION = '20200515' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 3HSNMTNOB02MKCLT5PJR4ZUKFJQX5NRE42GDZZZIU2LVGGU1
# CLIENT_SECRET:HPPDIJIDWVYKR1HKDQCJDTLE4I2WSBCULOSI0JKUTQJ1RQGO

# %% [markdown]
# Define the corresponding URL and mine the hotels data

# %%
radius = 1000
LIMIT = 200
search_query = 'hotel'
venues = []

for lat, long, post, borough, neighborhood in zip(df_combined['Latitude'], df_combined['Longitude'], df_combined['Postal Code'], df_combined['Borough'], df_combined['Neighborhood']):
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&query={}&radius={}&limit={}".format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        lat,
        long,
        search_query,
        radius, 
        LIMIT)
    
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    for venue in results:
        venues.append((
            post, 
            borough,
            neighborhood,
            lat, 
            long, 
            venue['venue']['name'], 
            venue['venue']['location']['lat'], 
            venue['venue']['location']['lng'],  
            venue['venue']['categories'][0]['name']))

# %%
venues_df = pd.DataFrame(venues)
venues_df.columns = ['PostalCode', 'Borough', 'Neighborhood', 'BoroughLatitude', 'BoroughLongitude', 'VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']
venues_df = venues_df[venues_df['VenueCategory'] == 'Hotel']
print(venues_df.shape)
venues_df.head()
# Out:
# (438, 9)
#   PostalCode           Borough                                 Neighborhood  \
# 1        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 6        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 7        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#    BoroughLatitude  BoroughLongitude                      VenueName  \
# 1        43.654260        -79.360636  Residence & Conference Centre
# 3        43.654260        -79.360636         Filmores Hotel Toronto
# 5        43.662301        -79.389494             The Hazelton Hotel
# 6        43.662301        -79.389494             Windsor Arms Hotel
# 7        43.662301        -79.389494           DoubleTree by Hilton
#
#    VenueLatitude  VenueLongitude VenueCategory
# 1      43.653040      -79.357040         Hotel
# 3      43.658019      -79.370326         Hotel
# 5      43.670764      -79.393257         Hotel
# 6      43.668781      -79.390850         Hotel
# 7      43.654608      -79.385942         Hotel

# %%
class_n = pd.DataFrame(venues_df['Neighborhood'].value_counts())
class_n.rename(columns = {'Neighborhood':'NofHotels'}, inplace=True)
class_n.head()
# Out:
#                                           NofHotels
# Richmond, Adelaide, King                         49
# First Canadian Place, Underground city           44
# Toronto Dominion Centre, Design Exchange         43
# Commerce Court, Victoria Hotel                   39
# St. James Town                                   38

# %% [markdown]
# Define the corresponding URL and mine the cafes data

# %%
radius = 500
LIMIT = 100
search_query = 'cafe'
cafes = []

for lat, long, post, borough, neighborhood in zip(df_combined['Latitude'], df_combined['Longitude'], df_combined['Postal Code'], df_combined['Borough'], df_combined['Neighborhood']):
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&query={}&radius={}&limit={}".format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        lat,
        long,
        search_query,
        radius, 
        LIMIT)
    
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    for venue in results:
        cafes.append((
            post, 
            borough,
            neighborhood,
            lat, 
            long, 
            venue['venue']['name'], 
            venue['venue']['location']['lat'], 
            venue['venue']['location']['lng'],  
            venue['venue']['categories'][0]['name']))

# %%
cafes_df = pd.DataFrame(cafes)
cafes_df.columns = ['PostalCode', 'Borough', 'Neighborhood', 'BoroughLatitude', 'BoroughLongitude', 'VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']
print(cafes_df.shape)
cafes_df.head()
# Out:
# (504, 9)
#   PostalCode           Borough               Neighborhood  BoroughLatitude  \
# 0        M5A  Downtown Toronto  Regent Park, Harbourfront         43.65426
# 1        M5A  Downtown Toronto  Regent Park, Harbourfront         43.65426
# 2        M5A  Downtown Toronto  Regent Park, Harbourfront         43.65426
# 3        M5A  Downtown Toronto  Regent Park, Harbourfront         43.65426
# 4        M5A  Downtown Toronto  Regent Park, Harbourfront         43.65426
#
#    BoroughLongitude           VenueName  VenueLatitude  VenueLongitude  \
# 0        -79.360636  Morning Glory Cafe      43.653947      -79.361149
# 1        -79.360636      Impact Kitchen      43.656369      -79.356980
# 2        -79.360636           Starbucks      43.651613      -79.364917
# 3        -79.360636         Caffe Furbo      43.649970      -79.358849
# 4        -79.360636     ODIN Cafe + Bar      43.656739      -79.356503
#
#   VenueCategory
# 0          Café
# 1          Café
# 2          Café
# 3          Café
# 4          Café

# %%
class_nn = pd.DataFrame(cafes_df['Neighborhood'].value_counts())
class_nn.rename(columns = {'Neighborhood':'NofCafes'}, inplace=True)
class_nn.head()
# Out:
#                                           NofCafes
# Commerce Court, Victoria Hotel                  51
# First Canadian Place, Underground city          46
# St. James Town                                  42
# Toronto Dominion Centre, Design Exchange        41
# Richmond, Adelaide, King                        37

# %% [markdown]
# Combine data and find best Neighborhood to start a cafeteria

# %%
class_fin = pd.concat([class_n, class_nn], axis=1, join='inner')
a=pd.DataFrame(class_fin['NofHotels']-class_fin['NofCafes'])
a.columns = ['OptIndex']
b=pd.DataFrame(class_fin['NofHotels']+a['OptIndex'])
c = pd.concat([class_fin, a, b], axis=1, join='inner')
c.reset_index(inplace=True)
c.columns = ['Neighborhood','NofHotels', 'NofCafes','NofHotels-NofCafes', 'OptIndex']
c.sort_values('OptIndex', ascending=False,inplace=True)
c.reset_index(inplace=True)
c.drop('index', axis=1, inplace=True)
c.OptIndex = -c.OptIndex.min()+c.OptIndex
print("Neighborhood rating to start a cafeteria")
c
# Out:
# Neighborhood rating to start a cafeteria
#                                          Neighborhood  NofHotels  NofCafes  \
# 0                            Richmond, Adelaide, King         49        37
# 1            Toronto Dominion Centre, Design Exchange         43        41
# 2              First Canadian Place, Underground city         44        46
# 3                            Garden District, Ryerson         34        27
# 4   Harbourfront East, Union Station, Toronto Islands         27        14
# 5                                      Stn A PO Boxes         31        23
# 6                                         Berczy Park         23         9
# 7                                      St. James Town         38        42
# 8                      Commerce Court, Victoria Hotel         39        51
# 9                                Church and Wellesley         22        17
# 10        Queen's Park, Ontario Provincial Government         17        14
# 11                                 Central Bay Street         21        29
# 12                The Annex, North Midtown, Yorkville          5         4
# 13              Canada Post Gateway Processing Centre          3         1
# 14                        St. James Town, Cabbagetown          4         5
# 15                 North Toronto West,  Lawrence Park          1         2
# 16  Business reply mail Processing Centre, South C...          1         3
# 17  Summerhill West, Rathnelly, South Hill, Forest...          1         3
# 18                                         Davisville          2         5
# 19                                 Runnymede, Swansea          1         4
# 20                     University of Toronto, Harbord          5        13
# 21                        Willowdale, Willowdale East          3         9
# 22                           Little Portugal, Trinity          2         9
# 23       Brockton, Parkdale Village, Exhibition Place          1         7
# 24                          Regent Park, Harbourfront          2        10
# 25                                    Studio District          1         9
# 26          Kensington Market, Chinatown, Grange Park          6        27
#
#     NofHotels-NofCafes  OptIndex
# 0                   12        76
# 1                    2        60
# 2                   -2        57
# 3                    7        56
# 4                   13        55
# 5                    8        54
# 6                   14        52
# 7                   -4        49
# 8                  -12        42
# 9                    5        42
# 10                   3        35
# 11                  -8        28
# 12                   1        21
# 13                   2        20
# 14                  -1        18
# 15                  -1        15
# 16                  -2        14
# 17                  -2        14
# 18                  -3        14
# 19                  -3        13
# 20                  -8        12
# 21                  -6        12
# 22                  -7        10
# 23                  -6        10
# 24                  -8         9
# 25                  -8         8
# 26                 -21         0

# %%
df_location = df_combined.set_index('Neighborhood')
bv = c.set_index('Neighborhood')
bv_combined = pd.concat([bv, df_location], axis=1, join='inner')
bv_combined.reset_index(inplace=True)
bv_combined = bv_combined.head()
print("List of best 5 locations to start a cafeteria:")
bv_combined
# Out:
# List of best 5 locations to start a cafeteria:
#                                         Neighborhood  NofHotels  NofCafes  \
# 0                           Richmond, Adelaide, King         49        37
# 1           Toronto Dominion Centre, Design Exchange         43        41
# 2             First Canadian Place, Underground city         44        46
# 3                           Garden District, Ryerson         34        27
# 4  Harbourfront East, Union Station, Toronto Islands         27        14
#
#    NofHotels-NofCafes  OptIndex Postal Code           Borough   Latitude  \
# 0                  12        76         M5H  Downtown Toronto  43.650571
# 1                   2        60         M5K  Downtown Toronto  43.647177
# 2                  -2        57         M5X  Downtown Toronto  43.648429
# 3                   7        56         M5B  Downtown Toronto  43.657162
# 4                  13        55         M5J  Downtown Toronto  43.640816
#
#    Longitude
# 0 -79.384568
# 1 -79.381576
# 2 -79.382280
# 3 -79.378937
# 4 -79.381752

# %%
map_toronto_f = folium.Map(location=[latitude, longitude], zoom_start=15)

for lat, long, post, neigh in zip(bv_combined['Latitude'], bv_combined['Longitude'], bv_combined['Postal Code'], bv_combined['Neighborhood']):
    label = "{} ({})".format(neigh, post)
    popup = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, long],
        radius=5,
        popup=popup,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto_f)
    
map_toronto_f
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
